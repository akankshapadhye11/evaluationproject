# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('fraud.csv')
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df=df.drop(columns=["_c39"])
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %% [markdown]
# dropping the column has there is no data in it. the whole column has missing values

# %%
#Data visualization
#checking missing values
sns.heatmap(df.isnull())

# %% [markdown]
# There is no missing value in the dataset

# %%
#Statisticial Summary
df.describe().transpose()
# Out:
#                               count          mean           std         min  \
# months_as_customer           1000.0  2.039540e+02  1.151132e+02        0.00
# age                          1000.0  3.894800e+01  9.140287e+00       19.00
# policy_number                1000.0  5.462386e+05  2.570630e+05   100804.00
# policy_deductable            1000.0  1.136000e+03  6.118647e+02      500.00
# policy_annual_premium        1000.0  1.256406e+03  2.441674e+02      433.33
# umbrella_limit               1000.0  1.101000e+06  2.297407e+06 -1000000.00
# insured_zip                  1000.0  5.012145e+05  7.170161e+04   430104.00
# capital-gains                1000.0  2.512610e+04  2.787219e+04        0.00
# capital-loss                 1000.0 -2.679370e+04  2.810410e+04  -111100.00
# incident_hour_of_the_day     1000.0  1.164400e+01  6.951373e+00        0.00
# number_of_vehicles_involved  1000.0  1.839000e+00  1.018880e+00        1.00
# ...

# %% [markdown]
# 1. count is same for all the columns
# 2. mean is less than 50% for all the columns
# 3. some of the columns has huge difference between max and 75%

# %%
#Exploring target data variable
df.fraud_reported.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %% [markdown]
# As their are just 2 values in target variable, we are going to use logistic regression.

# %%
#visualization
sns.countplot(x='fraud_reported', data=df);
print(df['fraud_reported'].value_counts())
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# for 'N' count is 753 and for 'Y' count is 247 so therefore dataset is imbalanced.

# %%
sns.countplot(x='policy_state', data=df);
print(df['policy_state'].value_counts())
# Out:
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64

# %% [markdown]
# maximum is OH(352) followed by IL(338) and IN(310)

# %%
sns.countplot(x='insured_sex', data=df);
print(df['insured_sex'].value_counts())
# Out:
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64

# %% [markdown]
# female count is more than male count.

# %%
sns.countplot(x='policy_deductable', data=df);
print(df['policy_deductable'].value_counts())
# Out:
# 1000    351
# 500     342
# 2000    307
# Name: policy_deductable, dtype: int64

# %% [markdown]
# maximum deductable price is Rs.1000 with count of 351 followed by Rs.500 with count of 342 and Rs.2000 with the count of 307

# %%
sns.countplot(x='incident_type', data=df);
print(df['incident_type'].value_counts())
# Out:
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64

# %% [markdown]
# maximum is multi-vehicle collision followed by single-vehicle collision, vehicle theft and parked car

# %%
sns.countplot(x='incident_city', data=df);
print(df['incident_city'].value_counts())
# Out:
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64

# %% [markdown]
# maximum incident city is springfield

# %%
sns.countplot(x='incident_state', data=df);
print(df['incident_state'].value_counts())
# Out:
# NY    262
# SC    248
# WV    217
# NC    110
# VA    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64

# %% [markdown]
# maximum incident state is NY

# %%
sns.countplot(x='insured_occupation', data=df);
print(df['insured_occupation'].value_counts())
# Out:
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# priv-house-serv      71
# other-service        71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64

# %% [markdown]
# machine-op-inspct working people clamined maximum insurance and less people are from farming-fishing

# %%
sns.countplot(x='insured_relationship', data=df);
print(df['insured_relationship'].value_counts())
# Out:
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64

# %% [markdown]
# maximum insured relationship is own child

# %%
#replacing '?' 
df['police_report_available']=df['police_report_available'].replace("?",np.nan)

# %%
sns.countplot(x='police_report_available', data=df);
print(df['police_report_available'].value_counts())
# Out:
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %% [markdown]
# in maximum cases police report is NOT available

# %%
sns.countplot(x='witnesses', data=df);
print(df['witnesses'].value_counts())
# Out:
# 1    258
# 2    250
# 0    249
# 3    243
# Name: witnesses, dtype: int64

# %% [markdown]
# maximum side atleast 1 witness is required

# %%
sns.countplot(x='incident_hour_of_the_day', data=df);
print(df['incident_hour_of_the_day'].value_counts())
# Out:
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 4     46
# 13    46
# 10    46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 7     40
# 19    40
# 12    40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: incident_hour_of_the_day, dtype: int64

# %% [markdown]
# maximum incidents are occured time is 17

# %%
sns.displot(df['policy_annual_premium'], kde= True)

# %% [markdown]
# data is normally distributed

# %%
#coverting string data into integer data using LabelEncoder
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585               532             2
# 1                   228   42         342868               821             1
# 2                   134   29         687698               186             2
# 3                   256   41         227811               766             0
# 4                   228   44         367455               181             0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851               487             2
# 996                 285   41         186934               129             0
# 997                 130   34         918516               509             2
# 998                 458   62         533940               573             0
# 999                 456   60         556080               359             2
#
# ...

# %%
#checking skewness
df.skew().sort_values()
# Out:
# vehicle_claim                 -0.621098
# total_claim_amount            -0.594582
# capital-loss                  -0.391472
# collision_type                -0.193345
# incident_state                -0.148865
# authorities_contacted         -0.121744
# auto_model                    -0.080773
# insured_hobbies               -0.061563
# insured_occupation            -0.058881
# auto_year                     -0.048289
# incident_hour_of_the_day      -0.035584
# policy_state                  -0.026177
# auto_make                     -0.018797
# insured_education_level       -0.000148
# police_report_available        0.000000
# incident_location              0.000000
# policy_annual_premium          0.004402
# incident_date                  0.004756
# policy_bind_date               0.005194
# bodily_injuries                0.014777
# witnesses                      0.019636
# policy_number                  0.038991
# incident_city                  0.049531
# ...

# %% [markdown]
# little skewness is present in the dataset

# %%
#checking correlation
dfcor=df.corr()
dfcor
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_bind_date                       0.055055  0.056538       0.045713
# policy_state                          -0.000328 -0.014533       0.072815
# policy_csl                            -0.026819 -0.015185       0.038917
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# insured_sex                            0.060925  0.073337       0.004564
# insured_education_level               -0.000833  0.000969      -0.037264
# ...

# %%
plt.figure(figsize=(30,25))
sns.heatmap(dfcor,cmap="Blues",annot=True)

# %%
plt.figure(figsize=(22,7))
df.corr()['fraud_reported'].sort_values(ascending=False).drop(['fraud_reported']).plot(kind='bar')
plt.xlabel('features')
plt.ylabel('column with target name')
plt.title('correlation')
plt.show()

# %% [markdown]
# 1. insured_occupation and auto_model is least correlated with target column
# 2. vehicle_claim is highly positive correlated with target column
# 3. incident_severity si highly negative correlated with target column

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(df.iloc[:,1:]))
z
# Out:
# array([[0.99083647, 0.09595307, 0.20949985, ..., 1.64574255, 0.1834404 ,
#         1.74601919],
#        [0.33407345, 0.79152739, 1.25939678, ..., 0.65747047, 0.31549088,
#         1.74601919],
#        [1.08891308, 0.55056594, 1.04747018, ..., 0.95970204, 0.31549088,
#         0.57273139],
#        ...,
#        [0.54161057, 1.44891961, 0.12594404, ..., 0.02857005, 1.5139238 ,
#         0.57273139],
#        [2.52328351, 0.04786687, 0.35844716, ..., 1.28637088, 1.18130295,
#         0.57273139],
#        [2.3043625 , 0.03830297, 0.41898517, ..., 0.65747047, 0.31549088,
#         0.57273139]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 31,  48,  88, 115, 119, 229, 248, 262, 314, 430, 458, 500, 503,
#        657, 700, 763, 807, 875, 922, 975], dtype=int64), array([ 7,  7,  7,  7,  7,  6,  6,  7,  7,  7,  7, 32,  7,  7,  7,  6, 15,
#         7,  7,  7], dtype=int64))

# %%
dfnew=df[(z<3).all(axis=1)]
dfnew
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585               532             2
# 1                   228   42         342868               821             1
# 2                   134   29         687698               186             2
# 3                   256   41         227811               766             0
# 4                   228   44         367455               181             0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851               487             2
# 996                 285   41         186934               129             0
# 997                 130   34         918516               509             2
# 998                 458   62         533940               573             0
# 999                 456   60         556080               359             2
#
# ...

# %% [markdown]
# 20 rows are dropped and outliers are treated

# %%
#separating columns into features and target
features=df.drop('fraud_reported',axis=1)
target=df['fraud_reported']

# %%
features
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585               532             2
# 1                   228   42         342868               821             1
# 2                   134   29         687698               186             2
# 3                   256   41         227811               766             0
# 4                   228   44         367455               181             0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851               487             2
# 996                 285   41         186934               129             0
# 997                 130   34         918516               509             2
# 998                 458   62         533940               573             0
# 999                 456   60         556080               359             2
#
# ...

# %%
target
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: fraud_reported, Length: 1000, dtype: int32

# %%
# Scaling the data using Min-Max Scaler
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=1)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the training accuracy is:- {r2_score(target_test,pred_test)}")
          
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.184334092660137
# At random state 0,the training accuracy is:- 0.20116536165286747
#
#
# At random state 1,the training accuracy is:- 0.184334092660137
# At random state 1,the training accuracy is:- 0.20116536165286747
#
#
# At random state 2,the training accuracy is:- 0.184334092660137
# At random state 2,the training accuracy is:- 0.20116536165286747
#
#
# At random state 3,the training accuracy is:- 0.184334092660137
# At random state 3,the training accuracy is:- 0.20116536165286747
#
#
# At random state 4,the training accuracy is:- 0.184334092660137
# At random state 4,the training accuracy is:- 0.20116536165286747
#
#
# At random state 5,the training accuracy is:- 0.184334092660137
# At random state 5,the training accuracy is:- 0.20116536165286747
#
#
# At random state 6,the training accuracy is:- 0.184334092660137
# At random state 6,the training accuracy is:- 0.20116536165286747
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.17613097287351742

# %%
# Cross-validation of the model
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold2 the cv score is 0.09002642170709407 and accuracy score for training is -0.18578272040349209 and accuracy for the testing is 0.17613097287351742
#
#
# At cross fold3 the cv score is 0.06323971648993809 and accuracy score for training is -0.18578272040349209 and accuracy for the testing is 0.17613097287351742
#
#
# At cross fold4 the cv score is 0.10251530860072494 and accuracy score for training is -0.18578272040349209 and accuracy for the testing is 0.17613097287351742
#
#
# At cross fold5 the cv score is 0.1091556321616169 and accuracy score for training is -0.18578272040349209 and accuracy for the testing is 0.17613097287351742
#
#
# At cross fold6 the cv score is 0.10499184355802572 and accuracy score for training is -0.18578272040349209 and accuracy for the testing is 0.17613097287351742
#
#
# At cross fold7 the cv score is 0.11044708050342311 and accuracy score for training is -0.18578272040349209 and accuracy for the testing is 0.17613097287351742
#
#
# ...

# %% [markdown]
# selecting cv=9

# %%
#Regularization
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,0.1,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
#final model training
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(features_train,target_train)
ls_score_training=ls.score(features_train,target_train)
pred_ls=ls.predict(features_test)
ls_score_training*100
# Out:
# 18.642588057849107

# %%
pred_ls=ls.predict(features_test)

# %%
lss=r2_score(target_test,pred_ls)
lss*100
# Out:
# 17.632868564164482

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 10.93991202069525

# %%
#Ensemble Technique
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train,target_train)
train_r2=rf.score(features_train,target_train)
pred_decision=rf.predict(features_test)
print('Training r2',train_r2)
rfs=r2_score(target_test,pred_decision)
print("R2Score:",rfs*100)
# Out:
# Training r2 0.8762785642020419
# R2Score: 29.86129385964914

# %%
import pickle
filename='insurance.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('insurance.pkl','rb'))
result=loaded_model.score(features_test,target_test)
print(result*100)
# Out:
# 29.86129385964914

# %%
conclusion=pd.DataFrame([loaded_model.predict(features_test)[:],pred_decision[:]],index=['predicted','original'])
conclusion.transpose()
# Out:
#      predicted  original
# 0         0.18      0.18
# 1         0.12      0.12
# 2         0.21      0.21
# 3         0.02      0.02
# 4         0.27      0.27
# ..         ...       ...
# 195       0.11      0.11
# 196       0.17      0.17
# 197       0.24      0.24
# 198       0.08      0.08
# 199       0.47      0.47
#
# [200 rows x 2 columns]
