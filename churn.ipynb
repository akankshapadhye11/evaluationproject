# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Data visualization
#checking missing values
sns.heatmap(df.isnull())

# %% [markdown]
# There is no missing values in the dataset

# %%
#Exploring target data variable
df.TotalCharges.unique()
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %% [markdown]
# column has continues data.

# %%
df.loc[df['TotalCharges']==" "]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# some columns has space as the value

# %%
df['TotalCharges']=df['TotalCharges'].replace(" ",np.nan)

# %%
#changing datatype of target variable
df['TotalCharges']=df['TotalCharges'].astype(float)

# %%
np.mean(df['TotalCharges'])
# Out:
# 2283.3004408418697

# %%
#making dataframe for nominal data
df_nominal=df[['gender', 'SeniorCitizen', 'Partner', 'Dependents',
        'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'Churn']].copy()

# %%
df_nominal.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
#visualization
sns.countplot(x='gender', data=df_nominal);
print(df_nominal['gender'].value_counts())
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %% [markdown]
# male count is more than female

# %%
sns.countplot(x='SeniorCitizen', data=df_nominal);
print(df_nominal['SeniorCitizen'].value_counts())
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# many customers are younger and total count of senior citizens are 1142

# %%
sns.countplot(x='Partner', data=df_nominal);
print(df_nominal['Partner'].value_counts())
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %% [markdown]
# many customers are unmarried

# %%
sns.countplot(x='Dependents', data=df_nominal);
print(df_nominal['Dependents'].value_counts())
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %% [markdown]
# maximum customers are not dependent

# %%
sns.countplot(x='PhoneService', data=df_nominal);
print(df_nominal['PhoneService'].value_counts())
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %% [markdown]
# almost 6361 customers has phone service

# %%
sns.countplot(x='MultipleLines', data=df_nominal);
print(df_nominal['MultipleLines'].value_counts())
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %% [markdown]
# customers using multiple services are 2971, not using multiple servies are 3390 and not using phone services are 682

# %%
sns.countplot(x='InternetService', data=df_nominal);
print(df_nominal['InternetService'].value_counts())
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %% [markdown]
# maximum customers are using fiber optic

# %%
sns.countplot(x='OnlineSecurity', data=df_nominal);
print(df_nominal['OnlineSecurity'].value_counts())
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64

# %% [markdown]
# 2019 customers has online security and 3498 has no online security

# %%
sns.countplot(x='OnlineBackup', data=df_nominal);
print(df_nominal['OnlineBackup'].value_counts())
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %% [markdown]
# 2429 people has online backup and 3088 has no backup

# %%
sns.countplot(x='DeviceProtection', data=df_nominal);
print(df_nominal['DeviceProtection'].value_counts())
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %% [markdown]
# 3095 has no device protection and 2422 has device protection

# %%
sns.countplot(x='TechSupport', data=df_nominal);
print(df_nominal['TechSupport'].value_counts())
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %% [markdown]
# 3473 has no tech support and 2044 has tech support

# %%
sns.countplot(x='StreamingTV', data=df_nominal);
print(df_nominal['StreamingTV'].value_counts())
# Out:
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64

# %% [markdown]
# 2810 has no streaming tv and 2707 has streaming tv

# %%
sns.countplot(x='StreamingMovies', data=df_nominal);
print(df_nominal['StreamingMovies'].value_counts())
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64

# %% [markdown]
# 2732 has streaming movies and 2785 has no streaming movies

# %%
sns.countplot(x='Contract', data=df_nominal);
print(df_nominal['Contract'].value_counts())
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %% [markdown]
# 3875 customers has month to month contract, 1695 has 2years contract and 1473 has 1year contract

# %%
sns.countplot(x='PaperlessBilling', data=df_nominal);
print(df_nominal['PaperlessBilling'].value_counts())
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %% [markdown]
# 4171 has paperless billing

# %%
sns.countplot(x='PaymentMethod', data=df_nominal);
print(df_nominal['PaymentMethod'].value_counts())
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %% [markdown]
# 2365 has electronic check, 1612 has mailed check, 1544 has bank transfer and 1522 has creditcard payment mode.

# %%
sns.countplot(x='Churn', data=df_nominal);
print(df_nominal['Churn'].value_counts())
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
#dataframe for ordinal data
df_ordinal=df[['customerID','tenure']].copy()

# %%
sns.catplot(x='SeniorCitizen',y='tenure', data=df)

# %% [markdown]
# data is equally distributed for customers who are not senior citizen and data is not equally distributed for senior citizens

# %%
#checking distribution of continuous data of float type column
df_cont=df[['MonthlyCharges','TotalCharges']].copy()

# %%
sns.displot(df_cont['TotalCharges'], kde= True)

# %% [markdown]
# no normal distribution of data

# %%
sns.displot(df_cont['MonthlyCharges'], kde= True)

# %% [markdown]
# data is not normally distributed

# %%
#coverting string data into integer data using LabelEncoder
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
#Statisticial Summary
df.describe().transpose()
# Out:
#                    count         mean          std    min      25%       50%  \
# customerID        7043.0  3521.000000  2033.283305   0.00  1760.50  3521.000
# gender            7043.0     0.504756     0.500013   0.00     0.00     1.000
# SeniorCitizen     7043.0     0.162147     0.368612   0.00     0.00     0.000
# Partner           7043.0     0.483033     0.499748   0.00     0.00     0.000
# Dependents        7043.0     0.299588     0.458110   0.00     0.00     0.000
# tenure            7043.0    32.371149    24.559481   0.00     9.00    29.000
# PhoneService      7043.0     0.903166     0.295752   0.00     1.00     1.000
# MultipleLines     7043.0     0.940508     0.948554   0.00     0.00     1.000
# InternetService   7043.0     0.872923     0.737796   0.00     0.00     1.000
# OnlineSecurity    7043.0     0.790004     0.859848   0.00     0.00     1.000
# OnlineBackup      7043.0     0.906432     0.880162   0.00     0.00     1.000
# ...

# %% [markdown]
# 1. count is same for all the columns
# 2. for some columns mean is greater than 50% and for some columns mean is lesser than 50%
# 3. for many columns max and 75% is same and for some columns there is a difference between max and 75%

# %%
#correaltion of columns with targeted column
df.corr()['TotalCharges'].sort_values()
# Out:
# PaymentMethod      -0.330594
# Churn              -0.199484
# InternetService    -0.175691
# customerID         -0.000270
# gender              0.000048
# Dependents          0.064653
# SeniorCitizen       0.102411
# PhoneService        0.113008
# PaperlessBilling    0.157830
# OnlineSecurity      0.254473
# TechSupport         0.276890
# Partner             0.319072
# OnlineBackup        0.375556
# DeviceProtection    0.389066
# StreamingTV         0.392472
# StreamingMovies     0.398088
# Contract            0.450306
# MultipleLines       0.453202
# MonthlyCharges      0.651065
# tenure              0.825880
# TotalCharges        1.000000
# Name: TotalCharges, dtype: float64

# %% [markdown]
# gender and customerID has least correlation with target variable

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),cmap="Blues",annot=True)

# %%
plt.figure(figsize=(22,7))
df.corr()['TotalCharges'].sort_values(ascending=False).drop(['TotalCharges']).plot(kind='bar')
plt.xlabel('features')
plt.ylabel('column with target name')
plt.title('correlation')
plt.show()

# %% [markdown]
# 1. total charges is highly correlated with tenure followed by monthlycharges.
# 2. gender and customeriD is least correlated.
# 3. churn, payment mode and internet services is negatively correlated with total charges

# %%
df.skew().sort_values()
# Out:
# PhoneService       -2.727153
# PaperlessBilling   -0.375396
# MonthlyCharges     -0.220524
# PaymentMethod      -0.170129
# gender             -0.019031
# customerID          0.000000
# StreamingMovies     0.014657
# StreamingTV         0.028486
# Partner             0.067922
# MultipleLines       0.118719
# OnlineBackup        0.182930
# DeviceProtection    0.186847
# InternetService     0.205423
# tenure              0.239540
# TechSupport         0.402365
# OnlineSecurity      0.416985
# Contract            0.630959
# Dependents          0.875199
# TotalCharges        0.961642
# Churn               1.063031
# SeniorCitizen       1.833633
# dtype: float64

# %% [markdown]
# 1. customerID has 0skewness
# 2. rest of the columns has considerable skewenss.
# hence we will not treat them

# %%
#finding outliers
df.plot(kind='box',subplots=True,figsize=(20,20),layout=(6,6))
# Out:
# customerID             AxesSubplot(0.125,0.772143;0.110714x0.107857)
# gender              AxesSubplot(0.257857,0.772143;0.110714x0.107857)
# SeniorCitizen       AxesSubplot(0.390714,0.772143;0.110714x0.107857)
# Partner             AxesSubplot(0.523571,0.772143;0.110714x0.107857)
# Dependents          AxesSubplot(0.656429,0.772143;0.110714x0.107857)
# tenure              AxesSubplot(0.789286,0.772143;0.110714x0.107857)
# PhoneService           AxesSubplot(0.125,0.642714;0.110714x0.107857)
# MultipleLines       AxesSubplot(0.257857,0.642714;0.110714x0.107857)
# InternetService     AxesSubplot(0.390714,0.642714;0.110714x0.107857)
# OnlineSecurity      AxesSubplot(0.523571,0.642714;0.110714x0.107857)
# OnlineBackup        AxesSubplot(0.656429,0.642714;0.110714x0.107857)
# DeviceProtection    AxesSubplot(0.789286,0.642714;0.110714x0.107857)
# TechSupport            AxesSubplot(0.125,0.513286;0.110714x0.107857)
# StreamingTV         AxesSubplot(0.257857,0.513286;0.110714x0.107857)
# ...

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([   0,    3,    7,   20,   27,   62,   81,   89,  103,  105,  107,
#          114,  116,  129,  131,  133,  168,  180,  185,  187,  206,  211,
#          215,  216,  217,  225,  236,  252,  255,  259,  260,  263,  272,
#          278,  303,  321,  324,  328,  348,  354,  358,  372,  376,  382,
#          387,  398,  424,  431,  435,  452,  465,  481,  488,  495,  498,
#          544,  569,  596,  610,  616,  620,  634,  660,  667,  669,  674,
#          677,  688,  716,  718,  735,  765,  776,  784,  790,  794,  813,
#          829,  843,  847,  859,  866,  873,  875,  877,  884,  893,  917,
#          934,  941,  943,  960,  973, 1011, 1018, 1037, 1050, 1051, 1053,
#         1072, 1110, 1119, 1122, 1144, 1146, 1150, 1161, 1169, 1182, 1204,
#         1221, 1225, 1242, 1255, 1257, 1271, 1278, 1298, 1311, 1326, 1331,
#         1333, 1334, 1340, 1349, 1352, 1365, 1379, 1402, 1407, 1416, 1452,
#         1479, 1480, 1481, 1500, 1506, 1513, 1519, 1560, 1562, 1581, 1584,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 4           6511       0              0        0           0       2
# 5           6551       0              0        0           0       8
# 6           1002       1              0        0           1      22
# ...          ...     ...            ...      ...         ...     ...
# 7037        1758       0              0        0           0      72
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %% [markdown]
# outliers are removed and 682 rows are dropped.

# %%
#separating columns into features and target
features=df.drop('TotalCharges',axis=1)
target=df['TotalCharges']

# %%
# Scaling the data using Min-Max Scaler
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,1000):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=1)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the training accuracy is:- {r2_score(target_test,pred_test)}")
          
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.09337823660960531
# At random state 0,the training accuracy is:- 0.11288960871693865
#
#
# At random state 1,the training accuracy is:- 0.09337823660960531
# At random state 1,the training accuracy is:- 0.11288960871693865
#
#
# At random state 2,the training accuracy is:- 0.09337823660960531
# At random state 2,the training accuracy is:- 0.11288960871693865
#
#
# At random state 3,the training accuracy is:- 0.09337823660960531
# At random state 3,the training accuracy is:- 0.11288960871693865
#
#
# At random state 4,the training accuracy is:- 0.09337823660960531
# At random state 4,the training accuracy is:- 0.11288960871693865
#
#
# At random state 5,the training accuracy is:- 0.09337823660960531
# At random state 5,the training accuracy is:- 0.11288960871693865
#
#
# At random state 6,the training accuracy is:- 0.09337823660960531
# At random state 6,the training accuracy is:- 0.11288960871693865
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.1145545954492615

# %%
# Cross-validation of the model
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold2 the cv score is 0.09081517377277382 and accuracy score for training is -0.0844702957255834 and accuracy for the testing is 0.1145545954492615
#
#
# At cross fold3 the cv score is 0.0947088453814842 and accuracy score for training is -0.0844702957255834 and accuracy for the testing is 0.1145545954492615
#
#
# At cross fold4 the cv score is 0.09022783011869814 and accuracy score for training is -0.0844702957255834 and accuracy for the testing is 0.1145545954492615
#
#
# At cross fold5 the cv score is 0.09293809107635238 and accuracy score for training is -0.0844702957255834 and accuracy for the testing is 0.1145545954492615
#
#
# At cross fold6 the cv score is 0.09167708954263852 and accuracy score for training is -0.0844702957255834 and accuracy for the testing is 0.1145545954492615
#
#
# At cross fold7 the cv score is 0.09212249954721805 and accuracy score for training is -0.0844702957255834 and accuracy for the testing is 0.1145545954492615
#
#
# ...

# %% [markdown]
# selected cv=6

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual chargers',fontsize=14)
plt.ylabel('Predicted chargers',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.savefig('lr.png')
plt.show()

# %%
#Regularization
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,0.1,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
#final model training
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(features_train,target_train)
ls_score_training=ls.score(features_train,target_train)
pred_ls=ls.predict(features_test)
ls_score_training*100
# Out:
# 9.31376692735909

# %%
pred_ls=ls.predict(features_test)

# %%
lss=r2_score(target_test,pred_ls)
lss*100
# Out:
# 11.455462655346127

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 9.293810857214224

# %%
#Ensemble Technique
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train,target_train)
train_r2=rf.score(features_train,target_train)
pred_decision=rf.predict(features_test)
print('Training r2',train_r2)
rfs=r2_score(target_test,pred_decision)
print("R2Score:",rfs*100)
# Out:
# Training r2 0.9779136737070971
# R2Score: 85.87574073481834

# %%
import pickle
filename='churn.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('churn.pkl','rb'))
result=loaded_model.score(features_test,target_test)
print(result*100)
# Out:
# 85.87574073481834

# %%
conclusion=pd.DataFrame([loaded_model.predict(features_test)[:],pred_decision[:]],index=['predicted','original'])
conclusion.transpose()
# Out:
#       predicted  original
# 0      5765.270  5765.270
# 1      2620.770  2620.770
# 2      1087.520  1087.520
# 3      1109.425  1109.425
# 4      3116.410  3116.410
# ...         ...       ...
# 1404   3482.170  3482.170
# 1405   2693.950  2693.950
# 1406   5503.140  5503.140
# 1407    463.700   463.700
# 1408   4403.570  4403.570
#
# [1409 rows x 2 columns]
