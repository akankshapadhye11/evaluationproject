# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_excel('Country-Code.xlsx')
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df2=pd.read_csv('zomato.csv')
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
#merging 2 dataset
df=pd.merge(df1,df2)

# %%
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.dtypes
# Out:
# Country Code              int64
# Country                  object
# Restaurant ID             int64
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Country Code', 'Country', 'Restaurant ID', 'Restaurant Name', 'City',
#        'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#Data visualization
#checking missing values
sns.heatmap(df.isnull())

# %% [markdown]
# There is no missing value in the dataset

# %%
#Exploring target data variable
df['Average Cost for two'].unique()
# Out:
# array([   850,    700,    500,    400,   1000,   2000,   2500,    800,
#          3600,      0,    550,   1100,   1500,    900,   1800,    300,
#          1400,    350,    450,    600,    950,   1200,    200,    100,
#           150,    650,   1300,   2400,    250,   1600,   2200,    750,
#          1700,   1250,   1900,   2700,   3500,   5000,   2300,   1750,
#          3200,   3000,   2100,   1850,   4500,   4000,   3300,    120,
#          1350,   1650,   1950,   1050,    290,     50,   1450,   2800,
#           260,   3650,   4800,   1550,    720,   6500,   7000,   1150,
#          2900,   2600,   4700,   3700,   3800,   4100,   4300,   2650,
#          6000,   5100,   5500,   4400,   4200,   8000,   2350,     20,
#             7,     30,     55,     45,     60,     80,     90,    230,
#           240,    140,    170,     40,     70,     85,     75,     65,
#            25, 150000,  70000, 250000, 200000, 165000, 800000, 500000,
# ...

# %% [markdown]
# multiple variables

# %%
#Exploring target data variable
df['Price range'].unique()
# Out:
# array([3, 2, 4, 1], dtype=int64)

# %% [markdown]
# there are 4 variables

# %%
#checking price range column
sns.countplot(x='Price range', data=df);
print(df['Price range'].value_counts())
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# price range for 1 is maximum with count 4444, followed by 2 for 3113, than 3 for 1408 and finally 4 for 586

# %%
sns.countplot(x='Rating color', data=df);
print(df['Rating color'].value_counts())
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %% [markdown]
# orange rating color is maximum with the count 3737, followed by white with 2148 and minimum is red with 186

# %%
sns.countplot(x='Has Table booking', data=df);
print(df['Has Table booking'].value_counts())
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %% [markdown]
# maximum count is for NO table booking and for yes it is just 1158

# %%
sns.countplot(x='Has Online delivery', data=df);
print(df['Has Online delivery'].value_counts())
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %% [markdown]
# maximum restaurants doesnt have online delivery

# %%
sns.countplot(x='Is delivering now', data=df);
print(df['Is delivering now'].value_counts())
# Out:
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64

# %% [markdown]
# delivering now has maximum no with count 9517 and yes with count 34

# %%
sns.countplot(x='Rating text', data=df);
print(df['Rating text'].value_counts())
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %% [markdown]
# maximum rating is for average followed by not rated, good, very good, excellent and minimum to the poor

# %%
sns.countplot(x='Currency', data=df);
print(df['Currency'].value_counts())
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(��)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Sri Lankan Rupee(LKR)       20
# Qatari Rial(QR)             20
# Name: Currency, dtype: int64

# %% [markdown]
# indian rupee has maximum count, followed by dollars and minimum of srilankan rupee and qatari rial

# %%
sns.countplot(x='Aggregate rating', data=df);
print(df['Aggregate rating'].value_counts())
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %% [markdown]
# 0.0 is the maximum and 1.8 is the minimum

# %%
print(df['Cuisines'].value_counts())
# Out:
# North Indian                   936
# North Indian, Chinese          511
# Chinese                        354
# Fast Food                      354
# North Indian, Mughlai          334
#                               ...
# Indonesian                       1
# North Indian, Awadhi             1
# Asian, Breakfast, Hawaiian       1
# Sushi, Thai                      1
# North Eastern, North Indian      1
# Name: Cuisines, Length: 1825, dtype: int64

# %% [markdown]
# maximum is for north india, chinese food and the lowest is for the asian sushi, italian, continental, thai

# %%
#coverting string data into integer data using LabelEncoder
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0                1        3        3400025             3201     1     4553
# 1                1        3        3400341             5261     1     4605
# 2                1        3        3400005             6919     1     6234
# 3                1        3        3400021             1637     1      100
# 4                1        3        3400017             4922     1     1316
# ...            ...      ...            ...              ...   ...      ...
# 9546           216       14       17697389             6794   135     1279
# 9547           216       14       17697424             6839   135     2667
# 9548           216       14       17697332             6945   135      957
# 9549           216       14       17694056             6883   136     1910
# 9550           216       14       17559793             2342   138      962
#
# ...

# %%
#Statisticial Summary
df.describe().transpose()
# Out:
#                        count          mean           std         min  \
# Country Code          9551.0  1.836562e+01  5.675055e+01    1.000000
# Country               9551.0  3.736781e+00  2.651963e+00    0.000000
# Restaurant ID         9551.0  9.051128e+06  8.791521e+06   53.000000
# Restaurant Name       9551.0  3.653205e+03  2.142918e+03    0.000000
# City                  9551.0  7.830143e+01  2.319891e+01    0.000000
# Address               9551.0  4.542439e+03  2.565717e+03    0.000000
# Locality              9551.0  6.581287e+02  3.158669e+02    0.000000
# Locality Verbose      9551.0  6.773052e+02  3.317278e+02    0.000000
# Longitude             9551.0  6.412657e+01  4.146706e+01 -157.948486
# Latitude              9551.0  2.585438e+01  1.100794e+01  -41.330428
# Cuisines              9551.0  9.899508e+02  5.147235e+02    0.000000
# Average Cost for two  9551.0  1.199211e+03  1.612118e+04    0.000000
# Currency              9551.0  3.977699e+00  9.142416e-01    0.000000
# ...

# %% [markdown]
# 1. count is same for all the columns.
# 2. for some columns mean is greater than 50% and for some columns mean is less than 50%
# 3. There is a difference between 75% and max for all the columns

# %%
#correaltion of columns with targeted column
df.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality               -0.012136
# Locality Verbose       -0.011852
# Country                -0.004034
# Is delivering now      -0.001862
# Restaurant ID          -0.001693
# Cuisines                0.005755
# Has Table booking       0.007758
# Restaurant Name         0.019241
# Address                 0.022749
# Rating text             0.031439
# Country Code            0.043225
# Currency                0.045615
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %%
#correaltion of columns with targeted column
df.corr()['Price range'].sort_values()
# Out:
# Latitude               -0.166688
# Rating color           -0.140468
# Restaurant ID          -0.134540
# Locality               -0.114457
# Locality Verbose       -0.112311
# City                   -0.105759
# Longitude              -0.078939
# Address                -0.034952
# Cuisines               -0.005489
# Is delivering now       0.010940
# Restaurant Name         0.061275
# Average Cost for two    0.075083
# Currency                0.075179
# Has Online delivery     0.077918
# Rating text             0.164242
# Country                 0.178035
# Country Code            0.243327
# Votes                   0.309444
# Aggregate rating        0.437944
# Has Table booking       0.501925
# Price range             1.000000
# Switch to order menu         NaN
# Name: Price range, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),cmap="Blues",annot=True)

# %%
#target variable has price range
plt.figure(figsize=(22,7))
df.corr()['Price range'].sort_values(ascending=False).drop(['Price range']).plot(kind='bar')
plt.xlabel('features')
plt.ylabel('column with target name')
plt.title('correlation')
plt.show()

# %% [markdown]
# 1. cuisines has the least correlation with target variable
# 2. has table booking is the highest positively correlated with target column
# 3. lattitude has the highest negatively correlated with target column

# %%
#target variable has avg cost for 2
plt.figure(figsize=(22,7))
df.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar')
plt.xlabel('features')
plt.ylabel('column with target name')
plt.title('correlation')
plt.show()

# %% [markdown]
# 1. restaurant id and delievering now has the least correlation with target variable
# 2. price range is the highest positively correlated with target column
# 3. lattitude has the highest negatively correlated with target column

# %%
df.skew().sort_values()
# Out:
# Latitude                -3.081635
# Longitude               -2.807328
# City                    -1.193777
# Aggregate rating        -0.954130
# Cuisines                -0.305484
# Locality                -0.253550
# Locality Verbose        -0.183059
# Address                 -0.040407
# Switch to order menu     0.000000
# Restaurant Name          0.044637
# Rating color             0.046009
# Restaurant ID            0.061570
# Rating text              0.431408
# Price range              0.889618
# Has Online delivery      1.114620
# Has Table booking        2.321100
# Currency                 2.858093
# Country Code             3.043965
# Country                  3.312721
# Votes                    8.807637
# Is delivering now       16.673412
# Average Cost for two    35.477915
# dtype: float64

# %% [markdown]
# skewness is present

# %%
#finding outliers
df.plot(kind='box',subplots=True,figsize=(20,20),layout=(6,6))
# Out:
# Country Code               AxesSubplot(0.125,0.772143;0.110714x0.107857)
# Country                 AxesSubplot(0.257857,0.772143;0.110714x0.107857)
# Restaurant ID           AxesSubplot(0.390714,0.772143;0.110714x0.107857)
# Restaurant Name         AxesSubplot(0.523571,0.772143;0.110714x0.107857)
# City                    AxesSubplot(0.656429,0.772143;0.110714x0.107857)
# Address                 AxesSubplot(0.789286,0.772143;0.110714x0.107857)
# Locality                   AxesSubplot(0.125,0.642714;0.110714x0.107857)
# Locality Verbose        AxesSubplot(0.257857,0.642714;0.110714x0.107857)
# Longitude               AxesSubplot(0.390714,0.642714;0.110714x0.107857)
# Latitude                AxesSubplot(0.523571,0.642714;0.110714x0.107857)
# Cuisines                AxesSubplot(0.656429,0.642714;0.110714x0.107857)
# Average Cost for two    AxesSubplot(0.789286,0.642714;0.110714x0.107857)
# Currency                   AxesSubplot(0.125,0.513286;0.110714x0.107857)
# ...

# %% [markdown]
# outliers are present in the columns aggregate rating, votes, currency, has table booking, is delievering now, price range, avg cost for 2, lallitude, longititude, city, country code, country

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(df.iloc[:,1:]))
z
# Out:
# array([[2.77839497e-01, 6.42823811e-01, 2.11033874e-01, ...,
#         1.37116966e+00, 1.24686228e-01, 3.93115898e-02],
#        [2.77839497e-01, 6.42787865e-01, 7.50322543e-01, ...,
#         1.37116966e+00, 1.24686228e-01, 1.99722008e-01],
#        [2.77839497e-01, 6.42826086e-01, 1.52407446e+00, ...,
#         1.37116966e+00, 1.24686228e-01, 1.46251869e-01],
#        ...,
#        [3.87024852e+00, 9.83522196e-01, 1.53620808e+00, ...,
#         1.37116966e+00, 1.24686228e-01, 2.11497108e-03],
#        [3.87024852e+00, 9.83149545e-01, 1.50727405e+00, ...,
#         1.37116966e+00, 1.24686228e-01, 2.11497108e-03],
#        [3.87024852e+00, 9.67876872e-01, 6.11910166e-01, ...,
#         6.38247498e-01, 1.05556963e+00, 3.27585385e-01]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550], dtype=int64), array([3, 3, 3, ..., 7, 0, 7], dtype=int64))

# %% [markdown]
# # Prediction with avg cost for two:

# %%
#separating data
x=df.drop('Average Cost for two',axis=1)
y=df['Average Cost for two']

# %%
x
# Out:
#       Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0                1        3        3400025             3201     1     4553
# 1                1        3        3400341             5261     1     4605
# 2                1        3        3400005             6919     1     6234
# 3                1        3        3400021             1637     1      100
# 4                1        3        3400017             4922     1     1316
# ...            ...      ...            ...              ...   ...      ...
# 9546           216       14       17697389             6794   135     1279
# 9547           216       14       17697424             6839   135     2667
# 9548           216       14       17697332             6945   135      957
# 9549           216       14       17694056             6883   136     1910
# 9550           216       14       17559793             2342   138      962
#
# ...

# %%
y
# Out:
# 0        850
# 1        700
# 2        500
# 3        400
# 4       1000
#         ...
# 9546      10
# 9547      10
# 9548      25
# 9549      25
# 9550      25
# Name: Average Cost for two, Length: 9551, dtype: int64

# %%
#removing skewness
import sklearn
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.32234518, -0.18994541,  0.14005679, ...,  1.32362428,
#          0.37685986,  0.79148481],
#        [-0.32234518, -0.18994541,  0.14009529, ...,  1.32362428,
#          0.37685986,  0.45845984],
#        [-0.32234518, -0.18994541,  0.14005435, ...,  1.32362428,
#          0.37685986,  0.59562488],
#        ...,
#        [ 3.10331548,  2.94974586,  0.93637249, ...,  1.32362428,
#          0.37685986,  0.84489311],
#        [ 3.10331548,  2.94974586,  0.93626911, ...,  1.32362428,
#          0.37685986,  0.84489311],
#        [ 3.10331548,  2.94974586,  0.93201872, ..., -0.59645668,
#         -1.16350271, -0.25138855]])

# %%
x=pd.DataFrame(x)  #coverting numpy to panda

# %%
x
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.322345 -0.189945  0.140057 -0.091271 -2.325059  0.092520 -2.103779
# 1    -0.322345 -0.189945  0.140095  0.770239 -2.325059  0.111613 -2.103779
# 2    -0.322345 -0.189945  0.140054  1.385730 -2.325059  0.684444 -2.103779
# 3    -0.322345 -0.189945  0.140056 -0.875733 -2.325059 -2.044174 -1.446100
# 4    -0.322345 -0.189945  0.140056  0.637156 -2.325059 -1.269536 -1.446100
# ...        ...       ...       ...       ...       ...       ...       ...
# 9546  3.103315  2.949746  0.936374  1.341108  3.469467 -1.288479  1.601817
# 9547  3.103315  2.949746  0.936375  1.357202  3.469467 -0.647615  1.601817
# 9548  3.103315  2.949746  0.936372  1.394979  3.469467 -1.460126  1.601817
# 9549  3.103315  2.949746  0.936269  1.372905  3.546753 -0.981839  1.607866
# 9550  3.103315  2.949746  0.932019 -0.501390  3.702696 -1.457354  1.638103
#
# ...

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
#standardizing the dataset
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_train
# Out:
# array([[-0.32372754, -0.19410539, -0.66692138, ..., -0.59681008,
#         -1.16916949,  0.65792175],
#        [-0.32372754, -0.19410539, -0.66259017, ...,  1.32515226,
#          0.36776628,  0.12351235],
#        [-0.32372754, -0.19410539,  0.95609543, ...,  1.32515226,
#          0.36776628,  0.98869554],
#        ...,
#        [-0.32372754, -0.19410539, -0.66450191, ..., -0.59681008,
#         -1.16916949, -0.6206418 ],
#        [-0.32372754, -0.19410539, -0.66217344, ...,  1.32515226,
#          0.36776628,  0.68830601],
#        [-0.32372754, -0.19410539, -0.6670036 , ..., -0.59681008,
#         -1.16916949,  0.08221244]])

# %%
x_test=st.transform(x_test)
x_test
# Out:
# array([[-0.32372754, -0.19410539, -0.66737432, ..., -0.59681008,
#         -1.16916949, -0.68514007],
#        [-0.32372754, -0.19410539, -0.65751504, ..., -0.59681008,
#         -1.16916949,  0.08221244],
#        [ 3.09006063,  2.8227504 ,  0.45584358, ..., -0.59681008,
#         -1.16916949, -0.0302542 ],
#        ...,
#        [ 3.09006112,  2.91523719,  0.92519645, ..., -0.59681008,
#         -1.16916949, -0.04864909],
#        [-0.32372754, -0.19410539, -0.65665379, ..., -1.34619409,
#          1.491629  ,  1.53669973],
#        [-0.32372754, -0.19410539,  0.9595994 , ...,  1.32515226,
#          0.36776628,  0.05261726]])

# %%
x_train.mean()
# Out:
# -4.4415860963281774e-18

# %%
x_train.std()
# Out:
# 0.9759000729485332

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 3.28792548e+03,  5.86674057e+02,  3.52891027e+02,  3.61955466e+02,
#        -4.45841746e+02,  6.45507419e+02, -6.21943733e+03,  6.11357015e+03,
#         2.90532972e+03, -2.52679373e+03,  1.52189563e+02,  9.00579526e+02,
#         4.95861157e+00, -2.62211553e+02, -3.79587871e+01,  4.06998879e-11,
#        -8.46996525e+01, -1.22201939e+03, -2.50930750e+02, -3.70063264e+02,
#         1.71570891e+03])

# %%
lm.intercept_
# Out:
# 1224.3956868260664

# %%
lm.score(x_train,y_train)
# Out:
# 0.053386273588100996

# %%
pred=lm.predict(x_test)
print("predicted prices",pred)
print("actual prices",y_test)
# Out:
# predicted prices [ 473.62002738 2748.38913453 -984.58402665 ... 1769.25784785  940.02445841
#    43.27791881]
# actual prices 4731    200
# 1468    700
# 9037     10
# 7866    500
# 5570    450
#        ...
# 4659    300
# 2314    500
# 9118     10
# 6226    900
# 5369    250
# Name: Average Cost for two, Length: 3152, dtype: int64

# %%
print("error:")
print("mean absolute error",mean_absolute_error(y_test,pred))
print("mean squared error",mean_squared_error(y_test,pred))
print("root mean squared error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# mean absolute error 2245.658462518122
# mean squared error 145355510.8189058
# root mean squared error 12056.347324911712

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.07075726667849258

# %%
p=np.array([1,3,3400025,3201,1,4553,17,17,78.011544,27.161661,0,4,0,0,0,0,3,3.9,5,2,140])
p=p.reshape(1,-1)
p.shape
# Out:
# (1, 21)

# %%
lm.predict(p)
# Out:
# array([1.20433476e+09])

# %%
# Regularization:: L1 L2
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.053364392827785934

# %%
ls.coef_
# Out:
# array([ 3288.2909209 ,   586.04277241,   351.98431416,   361.30582899,
#         -449.98160271,   647.97418531, -2794.19901814,  2689.81085287,
#         2905.00860431, -2524.97760404,   149.65120364,   900.50281953,
#            6.37408191,  -264.44436261,   -36.1832288 ,     0.        ,
#          -82.66844661, -1224.28832151,  -249.35109368,  -367.75792962,
#         1718.00961455])

# %%
print("mean absolute error",mean_absolute_error(y_test,pred))
print("mean squared error",mean_squared_error(y_test,pred))
print(r2_score(y_test,pred))
# Out:
# mean absolute error 2245.658462518122
# mean squared error 145355510.8189058
# 0.07075726667849258

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.053386273587894606

# %%
rd.coef_
# Out:
# array([ 3.28792537e+03,  5.86673992e+02,  3.52890889e+02,  3.61955400e+02,
#        -4.45842127e+02,  6.45507649e+02, -6.21910496e+03,  6.11323782e+03,
#         2.90532960e+03, -2.52679348e+03,  1.52189312e+02,  9.00579492e+02,
#         4.95873599e+00, -2.62211758e+02, -3.79586114e+01,  0.00000000e+00,
#        -8.46994043e+01, -1.22201935e+03, -2.50930601e+02, -3.70062963e+02,
#         1.71570884e+03])

# %%
print("mean absolute error",mean_absolute_error(y_test,pred))
print("mean squared error",mean_squared_error(y_test,pred))
print(r2_score(y_test,pred))
# Out:
# mean absolute error 2245.658462518122
# mean squared error 145355510.8189058
# 0.07075726667849258

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_
# Out:
# 0.05336281260826037
# array([ 3287.85487825,   585.9991648 ,   351.79487579,   361.27149121,
#         -450.07391254,   648.00863627, -2672.74538605,  2568.26580437,
#         2904.69066426, -2524.68566346,   149.550395  ,   900.41278391,
#            6.3834451 ,  -264.49086048,   -36.10756664,     0.        ,
#          -82.4306291 , -1223.53031815,  -249.30634814,  -367.42373687,
#         1717.19661786])

# %%
print("mean absolute error",mean_absolute_error(y_test,pred))
print("mean squared error",mean_squared_error(y_test,pred))
print(r2_score(y_test,pred))
# Out:
# mean absolute error 2245.658462518122
# mean squared error 145355510.8189058
# 0.07075726667849258

# %%
# Scaling the data using Min-Max Scaler
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the training accuracy is:- {r2_score(y_test,pred_test)}")
          
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.06572087870088528
# At random state 0,the training accuracy is:- 0.033720225711117435
#
#
# At random state 1,the training accuracy is:- 0.06572087870088528
# At random state 1,the training accuracy is:- 0.033720225711117435
#
#
# At random state 2,the training accuracy is:- 0.06572087870088528
# At random state 2,the training accuracy is:- 0.033720225711117435
#
#
# At random state 3,the training accuracy is:- 0.06572087870088528
# At random state 3,the training accuracy is:- 0.033720225711117435
#
#
# At random state 4,the training accuracy is:- 0.06572087870088528
# At random state 4,the training accuracy is:- 0.033720225711117435
#
#
# At random state 5,the training accuracy is:- 0.06572087870088528
# At random state 5,the training accuracy is:- 0.033720225711117435
#
#
# At random state 6,the training accuracy is:- 0.06572087870088528
# At random state 6,the training accuracy is:- 0.033720225711117435
#
#
# ...

# %%
# Cross-validation of the model
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold2 the cv score is -22.33966698199195 and accuracy score for training is 0.06572087870088528 and accuracy for the testing is 0.033720225711117435
#
#
# At cross fold3 the cv score is -21.921760823361623 and accuracy score for training is 0.06572087870088528 and accuracy for the testing is 0.033720225711117435
#
#
# At cross fold4 the cv score is -18.8853239050536 and accuracy score for training is 0.06572087870088528 and accuracy for the testing is 0.033720225711117435
#
#
# At cross fold5 the cv score is -17.588989331388667 and accuracy score for training is 0.06572087870088528 and accuracy for the testing is 0.033720225711117435
#
#
# At cross fold6 the cv score is -10.78785594276914 and accuracy score for training is 0.06572087870088528 and accuracy for the testing is 0.033720225711117435
#
#
# At cross fold7 the cv score is -9.44702381429999 and accuracy score for training is 0.06572087870088528 and accuracy for the testing is 0.033720225711117435
#
#
# ...

# %%
#Regularization
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,0.1,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
#final model training
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 6.570072539896232

# %%
pred_ls=ls.predict(x_test)

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 3.363697222662543

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# -1736.5403275983208

# %%
#Ensemble Technique
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(x_train,y_train)
train_r2=rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
print('Training r2',train_r2)
rfs=r2_score(y_test,pred_decision)
print("R2Score:",rfs*100)
# Out:
# Training r2 0.9245283389008887
# R2Score: 57.09993286236956

# %% [markdown]
# # prediction with price range using classification

# %%
#separating data
x1=df.drop('Price range',axis=1)
y1=df['Price range']

# %%
x1
# Out:
#       Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0                1        3        3400025             3201     1     4553
# 1                1        3        3400341             5261     1     4605
# 2                1        3        3400005             6919     1     6234
# 3                1        3        3400021             1637     1      100
# 4                1        3        3400017             4922     1     1316
# ...            ...      ...            ...              ...   ...      ...
# 9546           216       14       17697389             6794   135     1279
# 9547           216       14       17697424             6839   135     2667
# 9548           216       14       17697332             6945   135      957
# 9549           216       14       17694056             6883   136     1910
# 9550           216       14       17559793             2342   138      962
#
#       Locality  Locality Verbose   Longitude   Latitude  ...  \
# ...

# %%
y1
# Out:
# 0       3
# 1       2
# 2       2
# 3       2
# 4       3
#        ..
# 9546    1
# 9547    1
# 9548    2
# 9549    2
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %%
import sklearn
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=.33,random_state=42)

# %%
dtc=DecisionTreeClassifier()
sv=SVC()
knn=KNeighborsClassifier()

model=[dtc,sv,knn]

for m in model:
    m.fit(x1_train,y1_train)
    m.score(x1_train,y1_train)
    predm=m.predict(x1_test)
    print('accuracy score of',m,'is:')
    print(accuracy_score(y1_test,predm))
    print(confusion_matrix(y1_test,predm))
    print(classification_report(y1_test,predm))
    print('\n')
# Out:
# accuracy score of DecisionTreeClassifier() is:
# 0.9733502538071066
# [[1490    6    0    0]
#  [   8  958   11    0]
#  [   0   14  443   21]
#  [   0    0   24  177]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1496
#            2       0.98      0.98      0.98       977
#            3       0.93      0.93      0.93       478
#            4       0.89      0.88      0.89       201
#
#     accuracy                           0.97      3152
#    macro avg       0.95      0.95      0.95      3152
# weighted avg       0.97      0.97      0.97      3152
#
#
#
# accuracy score of SVC() is:
# 0.501269035532995
# [[1483    9    4    0]
#  [ 914   41   22    0]
#  [ 378   44   56    0]
#  [ 137   16   48    0]]
#               precision    recall  f1-score   support
#
#            1       0.51      0.99      0.67      1496
#            2       0.37      0.04      0.08       977
# ...

# %%
from sklearn.model_selection import cross_val_score

score=cross_val_score(sv,x1,y1,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.49136578 0.48062827 0.46544503 0.47434555 0.49633508]
# 0.4816239407563267
# 0.011198612040693882

# %%
score=cross_val_score(dtc,x1,y1,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.59811617 0.96806283 0.99895288 0.95811518 0.7104712 ]
# 0.8467436527571157
# 0.16166348646174564

# %%
score=cross_val_score(knn,x1,y1,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.48613291 0.48795812 0.53664921 0.4947644  0.4408377 ]
# 0.48926846775762256
# 0.030437571396523703

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(n_estimators=100,random_state=42)

rf.fit(x1_train,y1_train)
predrf=rf.predict(x1_test)
print(accuracy_score(y1_test,predrf))
print(confusion_matrix(y1_test,predrf))
print(classification_report(y1_test,predrf))
# Out:
# 0.9631979695431472
# [[1491    4    0    1]
#  [  10  957    9    1]
#  [   0   32  436   10]
#  [   0    4   45  152]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1496
#            2       0.96      0.98      0.97       977
#            3       0.89      0.91      0.90       478
#            4       0.93      0.76      0.83       201
#
#     accuracy                           0.96      3152
#    macro avg       0.94      0.91      0.92      3152
# weighted avg       0.96      0.96      0.96      3152

# %%
#saving the best model
import pickle
filename='zomato.pkl'
pickle.dump(dtc, open(filename, 'wb'))
#load the model from disk
loaded_model=pickle.load(open(filename,'rb'))
loaded_model.predict(x1_test)
# Out:
# array([1, 2, 1, ..., 1, 2, 1], dtype=int64)

# %% [markdown]
# decision tree classifier gives the accuracy of 97% so saving it as a best model

# %%
loaded_model=pickle.load(open('zomato.pkl','rb'))
result=loaded_model.score(x1_test,y1_test)
print(result*100)
# Out:
# 97.33502538071066
